# %%
"""
Smart Study Assistant - AI Chatbot
"""


study_answers = {
    "python": "Python is a programming language used for web development, data science, and AI.",
    "variable": "A variable stores data in memory. Example: x = 5",
    "function": "A function is a reusable block of code. Use 'def' to create one.",
    "list": "A list stores multiple items. Example: fruits = ['apple', 'banana']",
    "loop": "Loops repeat code. 'for' and 'while' are loop types in Python.",
    "if statement": "if/else statements make decisions in your code.",
    "dictionary": "Dictionaries store key-value pairs. Example: student = {'name': 'John'}",
}

def find_best_answer(question):
    """Simple AI - finds the most relevant answer"""
    question = question.lower()
    
    # Check for exact matches first
    for topic, answer in study_answers.items():
        if topic in question:
            return answer
# Out:
# Alice is 18 years old.
# Bob is 22 years old.
# Charlie is 30 years old.
